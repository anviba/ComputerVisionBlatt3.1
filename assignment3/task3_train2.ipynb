# %% [markdown]
# This is a simple example on how you can use a jupyter notebook to train your model :)

# %%
import torch
import torch.nn as nn
from importlib import reload  # Python 3.4+ only.
import dataloaders
from task2 import Trainer, compute_loss_and_accuracy, create_plots

# %%
def compute_output_pooling(w1, h1, d1, f, s):
    w2 = (w1 - f) / s + 1
    h2 = (h1 - f) / s + 1
    d2 = d1
    return w2, h2, d2

def compute_output_convolution(w1, h1, d1, fw, fh, pw, ph, sw, sh, num_filter):
    w2 = (w1 - fw + 2*pw) / sw + 1
    h2 = (h1 - fh + 2*ph) / sh + 1
    d2 = num_filter
    return w2, h2, d2

num_filters = 16
w1, h1, d1 = 32, 32, 3
fw, fh, pw, ph, sw, sh = 3, 3, 1, 1, 1, 1
f, s = 2, 2
for i in range(5):
    w1, h1, d1 = compute_output_convolution(w1, h1, d1, fw, fh, pw, ph, sw, sh, num_filters)
    num_filters *= 2
    w1, h1, d1 = compute_output_pooling(w1, h1, d1, f, s)
print(w1, h1, d1)
# Out:
# 1.0 1.0 256

# %%
class ExampleModel(nn.Module):

    def __init__(self,
                 image_channels,
                 num_classes):
        """
            Is called when model is initialized.
            Args:
                image_channels. Number of color channels in image (3)
                num_classes: Number of classes we want to predict (10)
        """
        super().__init__()
        fw, fh, pw, ph, sw, sh = 5,5,2,2,1,1
        f, s = 2, 2
        num_filters = 32  # Set number of filters in first conv layer
        self.num_classes = num_classes
        # Define the convolutional layers
        self.feature_extractor = nn.Sequential(
            nn.Conv2d(
                in_channels=image_channels,
                out_channels=num_filters,
                kernel_size=fh,
                stride=sh,
                padding=ph
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=f, stride=s),
            nn.Conv2d(
                in_channels=num_filters,
                out_channels=2*num_filters,
                kernel_size=fh,
                stride=sh,
                padding=ph
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=f, stride=s),
            nn.Conv2d(
                in_channels=2*num_filters,
                out_channels=4*num_filters,
                kernel_size=fh,
                stride=sh,
                padding=ph
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=f, stride=s),
            nn.Dropout2d(p=0.1),
        )
        # The output of feature_extractor will be [batch_size, num_filters, 16, 16]
        w1, h1, d1 = 32, 32, 3
        for i in range(3):
            w1, h1, d1 = compute_output_convolution(w1, h1, d1, fw, fh, pw, ph, sw, sh, num_filters)
            num_filters *= 2
            w1, h1, d1 = compute_output_pooling(w1, h1, d1, f, s)
        self.num_output_features = int(w1 * h1 * d1)
        # Initialize our last fully connected layer
        # Inputs all extracted features from the convolutional layers
        # Outputs num_classes predictions, 1 for each class.
        # There is no need for softmax activation function, as this is
        # included with nn.CrossEntropyLoss
        self.classifier = nn.Sequential(
            nn.Linear(self.num_output_features, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes),
        )

    def forward(self, x):
        """
        Performs a forward pass through the model
        Args:
            x: Input image, shape: [batch_size, 3, 32, 32]
        """
        batch_size = x.shape[0]
        out = self.feature_extractor(x)
        out = out.view(batch_size, -1)
        out = self.classifier(out)        
        expected_shape = (batch_size, self.num_classes)
        assert out.shape == (batch_size, self.num_classes),\
            f"Expected output of forward pass to be: {expected_shape}, but got: {out.shape}"
        return out

# %%
epochs = 10
batch_size = 64
learning_rate = 5e-2
early_stop_count = 4
dataloader = dataloaders.load_cifar10(batch_size)
model = ExampleModel(image_channels=3, num_classes=10)
trainer = Trainer(
    batch_size,
    learning_rate,
    early_stop_count,
    epochs,
    model,
    dataloader
)
trainer.train()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ExampleModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout2d(p=0.1)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=10, bias=True)
#   )
# )
# Epoch:  0	Batches per seconds: 172.69	Global step:    351	Validation Loss: 1.65,	Validation Accuracy: 0.407
# Epoch:  0	Batches per seconds: 141.29	Global step:    702	Validation Loss: 1.43,	Validation Accuracy: 0.492
# Epoch:  1	Batches per seconds: 131.44	Global step:   1053	Validation Loss: 1.30,	Validation Accuracy: 0.540
# Epoch:  1	Batches per seconds: 128.78	Global step:   1404	Validation Loss: 1.35,	Validation Accuracy: 0.528
# Epoch:  2	Batches per seconds: 127.72	Global step:   1755	Validation Loss: 1.16,	Validation Accuracy: 0.595
# Epoch:  2	Batches per seconds: 126.24	Global step:   2106	Validation Loss: 1.05,	Validation Accuracy: 0.636
# Epoch:  3	Batches per seconds: 124.86	Global step:   2457	Validation Loss: 0.92,	Validation Accuracy: 0.677
# Epoch:  3	Batches per seconds: 124.15	Global step:   2808	Validation Loss: 0.91,	Validation Accuracy: 0.676
# Epoch:  4	Batches per seconds: 122.79	Global step:   3159	Validation Loss: 0.92,	Validation Accuracy: 0.683
# Epoch:  4	Batches per seconds: 122.12	Global step:   3510	Validation Loss: 0.82,	Validation Accuracy: 0.708
# Epoch:  5	Batches per seconds: 121.22	Global step:   3861	Validation Loss: 0.79,	Validation Accuracy: 0.730
# Epoch:  5	Batches per seconds: 121.05	Global step:   4212	Validation Loss: 0.80,	Validation Accuracy: 0.722
# Epoch:  6	Batches per seconds: 121.30	Global step:   4563	Validation Loss: 0.78,	Validation Accuracy: 0.732
# Epoch:  6	Batches per seconds: 120.96	Global step:   4914	Validation Loss: 0.73,	Validation Accuracy: 0.747
# Epoch:  7	Batches per seconds: 120.53	Global step:   5265	Validation Loss: 0.72,	Validation Accuracy: 0.752
# Epoch:  7	Batches per seconds: 120.39	Global step:   5616	Validation Loss: 0.83,	Validation Accuracy: 0.723
# Epoch:  8	Batches per seconds: 120.72	Global step:   5967	Validation Loss: 0.72,	Validation Accuracy: 0.761
# Epoch:  8	Batches per seconds: 120.29	Global step:   6318	Validation Loss: 0.71,	Validation Accuracy: 0.758
# Epoch:  9	Batches per seconds: 120.24	Global step:   6669	Validation Loss: 0.68,	Validation Accuracy: 0.768
# Epoch:  9	Batches per seconds: 120.31	Global step:   7020	Validation Loss: 0.67,	Validation Accuracy: 0.773

# %%
create_plots(trainer, "task3_train2")
